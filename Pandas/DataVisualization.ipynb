# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.linspace(1,5,11)
x
y = x**2
y
# Out:
# array([ 1.  ,  1.96,  3.24,  4.84,  6.76,  9.  , 11.56, 14.44, 17.64,
#        21.16, 25.  ])

# %%
plt.plot(x,y)
plt.title("Graph")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
# Out:
# Text(0, 0.5, 'Y-Axis')

# %% [markdown]
# ### Subplot

# %%
plt.subplot(2,2,1)
plt.plot(x,y)
plt.subplot(2,2,2)
plt.plot(x**2,y)
plt.subplot(2,2,3)
plt.plot(y,y)
plt.subplot(2,2,4)
plt.plot(y,x)

# %%
fig = plt.figure(figsize=(10,8) )
axis1 = fig.add_axes([0.1,0.1,1,1])
axis1.plot(x,y)
axis2 = fig.add_axes([0.3,0.4,0.3,0.3])
axis2.plot(x,y)

# %%
plt.scatter(x,y)

# %%
plt.hist(x)
# Out:
# (array([1., 1., 1., 1., 1., 1., 1., 1., 1., 2.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1ceb9bb4a40>,
#   <matplotlib.lines.Line2D at 0x1ceba98bef0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1ceba904bc0>,
#   <matplotlib.lines.Line2D at 0x1ceba905730>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1ceba4f6900>],
#  'medians': [<matplotlib.lines.Line2D at 0x1ceba9c00e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1ceba9c0350>],
#  'means': []}
